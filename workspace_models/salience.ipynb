# %%
import os, sys
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
saliency = cv2.saliency.StaticSaliencySpectralResidual_create()
# saliency = cv2.saliency.StaticSaliencyFineGrained_create()

# %%
img = cv2.imread("./imgs/6_same.png")
(success, saliencyMap) = saliency.computeSaliency(img)
saliencyMap = (saliencyMap * 255).astype("uint8")
plt.imshow(saliencyMap, cmap = "gray")

# %%
img = cv2.imread("./imgs/6_different.png")
(success, saliencyMap) = saliency.computeSaliency(img)
saliencyMap = (saliencyMap * 255).astype("uint8")
plt.imshow(saliencyMap, cmap = "gray")

# %%
img = cv2.imread("./imgs/2_same.png")
(success, saliencyMap) = saliency.computeSaliency(img)
saliencyMap = (saliencyMap * 255).astype("uint8")
plt.imshow(saliencyMap, cmap = "gray")

# %%
img = cv2.imread("./imgs/2_different.png")
(success, saliencyMap) = saliency.computeSaliency(img)
saliencyMap = (saliencyMap * 255).astype("uint8")
plt.imshow(saliencyMap, cmap = "gray")

# %%
img = cv2.imread("./imgs/pacman_same.png")
(success, saliencyMap) = saliency.computeSaliency(img)
saliencyMap = (saliencyMap * 255).astype("uint8")
plt.figure()
plt.imshow(saliencyMap, cmap = "gray")
plt.show()
plt.figure()
plt.imshow(img)
plt.show()

# %%
img = cv2.imread("./imgs/pacman_different.png")
(success, saliencyMap) = saliency.computeSaliency(img)
saliencyMap = (saliencyMap * 255).astype("uint8")
plt.figure()
plt.imshow(saliencyMap, cmap = "gray")
plt.show()
plt.figure()
plt.imshow(img)
plt.show()

# %%
img = cv2.imread("./imgs/pacman_random1.png")
(success, saliencyMap) = saliency.computeSaliency(img)
saliencyMap = (saliencyMap * 255).astype("uint8")
plt.figure()
plt.imshow(saliencyMap, cmap = "gray")
plt.show()
plt.figure()
plt.imshow(img)
plt.show()

# %%
img = cv2.imread("./imgs/pacman_random2.png")
(success, saliencyMap) = saliency.computeSaliency(img)
saliencyMap = (saliencyMap * 255).astype("uint8")
plt.imshow(saliencyMap, cmap = "gray")
