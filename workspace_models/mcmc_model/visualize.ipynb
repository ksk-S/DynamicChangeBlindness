# %%
import csv
import math
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def create_data(ts, f1, f2, theta1, theta2, A1, A2, sigma=0.02):
    outs = []
    for t in range(ts):
        n_f1 = np.random.normal(0.0, 0.05)
        n_f2 = np.random.normal(0.0, 0.05)
        val = A1*math.sin(f1*t+theta1+n_f1) + A2*math.sin(f2*t+theta2+n_f2) + np.random.normal(0.0, sigma)
        outs.append(val)
    return np.array(outs)

# %%
plt.figure(figsize=(10, 7))
plt.plot(range(100), df["error"], label="prediction error")
plt.plot(range(100), df["alpha"], label="alpha")
plt.vlines([50], -1, 4, "blue", linestyles='dashed')
plt.legend()
plt.ylim([0.0, 3.5])
plt.show()

# %%
with open("./data/json/test_ekf_no_alpha2.json", "r") as f:
    json_dict = json.load(f)

error_arr = json_dict["y_errors"]
# alpha_arr = json_dict["alphas"]
preds = json_dict["preds"]
ys = json_dict["ys"]
K_gains = json_dict["k_gain"]

# %%
plt.figure(figsize=(10, 3))
plt.plot(range(len(alpha_arr)), alpha_arr, label="Alpha value", color="b")
plt.vlines([500], -1, 4, "grey", linestyles='dashed')
plt.vlines([1000], -1, 4, "grey", linestyles='dashed')
plt.vlines([1500], -1, 4, "grey", linestyles='dashed')
plt.legend()
plt.xlabel("time step")
plt.ylim([0.4, 0.7])

plt.figure(figsize=(10, 3))
plt.plot(range(len(error_arr)), error_arr, label="prediction error", color="g")
plt.vlines([500], -1, 4, "grey", linestyles='dashed')
plt.vlines([1000], -1, 4, "grey", linestyles='dashed')
plt.vlines([1500], -1, 4, "grey", linestyles='dashed')
plt.legend()
plt.xlabel("time step")
plt.ylim([0.0, 1.0])
# Out:
# (0.0, 1.0)

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(len(ys)), ys, label="target")
plt.plot(range(len(preds)), preds, label="prediction")
plt.vlines([500], -1.5, 1.5, "red", linestyles='dashed')
plt.vlines([1000], -1.5, 1.5, "red", linestyles='dashed')
plt.vlines([1500], -1.5, 1.5, "red", linestyles='dashed')
plt.xlabel("time step")
plt.legend()
plt.ylim([-1.5, 1.5])
# Out:
# (-1.5, 1.5)

# %%
K_gains = np.array(K_gains)

plt.figure(figsize=(10, 5))
plt.plot(range(len(K_gains)), K_gains[:,1], label="Kalman gain for theta2")
plt.plot(range(len(K_gains)), K_gains[:,0], label="Kalman gain for theta1")
plt.vlines([500], -1, 4, "grey", linestyles='dashed')
plt.vlines([1000], -1, 4, "grey", linestyles='dashed')
plt.vlines([1500], -1, 4, "grey", linestyles='dashed')
plt.legend()
plt.xlabel("time step")
plt.ylim([-0.1, 1.0])

plt.figure(figsize=(10, 3))
plt.plot(range(len(K_gains)), K_gains[:,0] - K_gains[:,1], label="$KG(\\theta_{1}) - KG(\\theta_{2})$", color="g")
plt.vlines([500], -1, 4, "grey", linestyles='dashed')
plt.vlines([1000], -1, 4, "grey", linestyles='dashed')
plt.vlines([1500], -1, 4, "grey", linestyles='dashed')
plt.hlines([0], 0, 2000, "grey", linestyles='dashed')
plt.legend()
plt.xlabel("time step")
plt.ylim([-0.5, 1.0])
# Out:
# (-0.5, 1.0)

# %%
with open("./data/json/test_ekf_no_alpha3.json", "r") as f:
    json_dict = json.load(f)

error_arr = json_dict["y_errors"]
# alpha_arr = json_dict["alphas"]
preds = json_dict["preds"]
ys = json_dict["ys"]
K_gains = json_dict["k_gain"]

K_gains = np.array(K_gains)

plt.figure(figsize=(10, 5))
plt.plot(range(len(K_gains)), K_gains[:,1], label="Kalman gain for theta2")
plt.plot(range(len(K_gains)), K_gains[:,0], label="Kalman gain for theta1")
plt.vlines([350], -1, 4, "grey", linestyles='dashed')
# plt.vlines([1000], -1, 4, "grey", linestyles='dashed')
# plt.vlines([1500], -1, 4, "grey", linestyles='dashed')
plt.legend()
plt.xlabel("time step")
plt.ylim([-0.1, 1.0])

plt.figure(figsize=(10, 3))
plt.plot(range(len(K_gains)), K_gains[:,0] - K_gains[:,1], label="$KG(\\theta_{1}) - KG(\\theta_{2})$", color="g")
plt.vlines([350], -1, 4, "grey", linestyles='dashed')
# plt.vlines([1000], -1, 4, "grey", linestyles='dashed')
# plt.vlines([1500], -1, 4, "grey", linestyles='dashed')
plt.hlines([0], 0, 1000, "grey", linestyles='dashed')
plt.legend()
plt.xlabel("time step")
plt.ylim([-0.5, 1.0])

plt.figure(figsize=(10, 5))
plt.plot(range(len(ys)), ys, label="target")
plt.plot(range(len(preds)), preds, label="prediction")
plt.vlines([350], -1.5, 1.5, "red", linestyles='dashed')
plt.xlabel("time step")
plt.legend()
plt.ylim([-1.5, 1.5])
# Out:
# (-1.5, 1.5)

# %%
with open("./data/json/test_ekf_no_alpha3.json", "r") as f:
    json_dict = json.load(f)

error_arr = json_dict["y_errors"]
# alpha_arr = json_dict["alphas"]
preds = json_dict["preds"]
ys = json_dict["ys"]
K_gains = json_dict["k_gain"]

K_gains = np.array(K_gains)

plt.figure(figsize=(10, 5))
plt.plot(range(len(K_gains)), K_gains[:,1], label="Kalman gain for theta2")
plt.plot(range(len(K_gains)), K_gains[:,0], label="Kalman gain for theta1")
plt.vlines([350], -1, 4, "grey", linestyles='dashed')
# plt.vlines([1000], -1, 4, "grey", linestyles='dashed')
# plt.vlines([1500], -1, 4, "grey", linestyles='dashed')
plt.legend()
plt.xlabel("time step")
plt.ylim([-0.1, 1.0])

plt.figure(figsize=(10, 3))
plt.plot(range(len(K_gains)), K_gains[:,0] - K_gains[:,1], label="$KG(\\theta_{1}) - KG(\\theta_{2})$", color="g")
plt.vlines([350], -1, 4, "grey", linestyles='dashed')
# plt.vlines([1000], -1, 4, "grey", linestyles='dashed')
# plt.vlines([1500], -1, 4, "grey", linestyles='dashed')
plt.hlines([0], 0, 1000, "grey", linestyles='dashed')
plt.legend()
plt.xlabel("time step")
plt.ylim([-0.5, 1.0])

plt.figure(figsize=(10, 5))
plt.plot(range(len(ys)), ys, label="target")
plt.plot(range(len(preds)), preds, label="prediction")
plt.vlines([350], -1.5, 1.5, "red", linestyles='dashed')
plt.xlabel("time step")
plt.legend()
plt.ylim([-1.5, 1.5])
# Out:
# (-1.5, 1.5)

# %%
with open("./data/json/test_ekf_no_alpha4.json", "r") as f:
    json_dict = json.load(f)

error_arr = json_dict["y_errors"]
# alpha_arr = json_dict["alphas"]
preds = json_dict["preds"]
ys = json_dict["ys"]
K_gains = json_dict["k_gain"]

K_gains = np.array(K_gains)

plt.figure(figsize=(10, 5))
plt.plot(range(len(K_gains)), K_gains[:,1], label="Kalman gain for theta2")
plt.plot(range(len(K_gains)), K_gains[:,0], label="Kalman gain for theta1")
plt.vlines([500], -1, 4, "grey", linestyles='dashed')
# plt.vlines([1000], -1, 4, "grey", linestyles='dashed')
# plt.vlines([1500], -1, 4, "grey", linestyles='dashed')
plt.legend()
plt.xlabel("time step")
plt.ylim([-0.1, 1.0])

plt.figure(figsize=(10, 3))
plt.plot(range(len(K_gains)), K_gains[:,0] - K_gains[:,1], label="$KG(\\theta_{1}) - KG(\\theta_{2})$", color="g")
plt.vlines([500], -1, 4, "grey", linestyles='dashed')
# plt.vlines([1000], -1, 4, "grey", linestyles='dashed')
# plt.vlines([1500], -1, 4, "grey", linestyles='dashed')
plt.hlines([0], 0, 1000, "grey", linestyles='dashed')
plt.legend()
plt.xlabel("time step")
plt.ylim([-0.5, 1.0])

plt.figure(figsize=(10, 5))
plt.plot(range(len(ys)), ys, label="target")
plt.plot(range(len(preds)), preds, label="prediction")
plt.vlines([500], -1.5, 1.5, "red", linestyles='dashed')
plt.xlabel("time step")
plt.legend()
plt.ylim([-1.5, 1.5])
# Out:
# (-1.5, 1.5)

# %%
with open("./data/json/test_ekf_no_alpha5.json", "r") as f:
    json_dict = json.load(f)

error_arr = json_dict["y_errors"]
# alpha_arr = json_dict["alphas"]
preds = json_dict["preds"]
ys = json_dict["ys"]
K_gains = json_dict["k_gain"]

K_gains = np.array(K_gains)

plt.figure(figsize=(10, 5))
plt.plot(range(len(K_gains)), K_gains[:,1], label="Kalman gain for theta2")
plt.plot(range(len(K_gains)), K_gains[:,0], label="Kalman gain for theta1")
plt.vlines([500], -1, 4, "grey", linestyles='dashed')
# plt.vlines([1000], -1, 4, "grey", linestyles='dashed')
# plt.vlines([1500], -1, 4, "grey", linestyles='dashed')
plt.legend()
plt.xlabel("time step")
plt.ylim([-0.1, 1.0])

plt.figure(figsize=(10, 3))
plt.plot(range(len(K_gains)), K_gains[:,0] - K_gains[:,1], label="$KG(\\theta_{1}) - KG(\\theta_{2})$", color="g")
plt.vlines([500], -1, 4, "grey", linestyles='dashed')
# plt.vlines([1000], -1, 4, "grey", linestyles='dashed')
# plt.vlines([1500], -1, 4, "grey", linestyles='dashed')
plt.hlines([0], 0, 1000, "grey", linestyles='dashed')
plt.legend()
plt.xlabel("time step")
plt.ylim([-0.5, 1.0])

plt.figure(figsize=(10, 5))
plt.plot(range(len(ys)), ys, label="target")
plt.plot(range(len(preds)), preds, label="prediction")
plt.vlines([500], -1.5, 1.5, "red", linestyles='dashed')
plt.xlabel("time step")
plt.legend()
plt.ylim([-1.5, 1.5])
# Out:
# (-1.5, 1.5)
